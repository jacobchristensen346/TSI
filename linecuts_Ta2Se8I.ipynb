# %% [markdown]
# - Below we have script to make plots showing difference between synchrotron and toby data for cdw satellites

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib

# %%
# 1001x1001 pixels experimental
# 511x511 pixels toby data
# each pixel in experimental is 0.01 reciprocal units
os.chdir('C:/Users/Jacob/Downloads/')
data1 = np.genfromtxt('Values2.csv', delimiter=',')
data2 = np.genfromtxt('Values1.csv', delimiter=',')

# %%
x1 = (data1[1:,0:1]*((2)/53))-max(data1[1:,0:1]*((2)/53))/2-0.02
y1 = data1[1:,1:2]
x2 = (data2[1:,0:1]*0.01)-max((data2[1:,0:1]*0.01))/2
y2 = data2[1:,1:2] - (min(data2[1:,1:2])-min(data1[1:,1:2]))

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
#plt.ylim(0,200)

# %%
# 1001x1001 pixels experimental
# 511x511 pixels toby data
# each pixel in experimental is 0.01 reciprocal units
os.chdir('F:/Jacob_Christensen/ed13w3_Ta2Se8I')
data1 = np.genfromtxt('lineplot_CDW_satellites_Toby_angled.csv', delimiter=',')
data2 = np.genfromtxt('lineplot_CDW_satellites_experimental_angled_secondary.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # 1001x1001 pixels experimental
#       2 # 511x511 pixels toby data
#       3 # each pixel in experimental is 0.01 reciprocal units
# ----> 4 os.chdir('F:/Jacob_Christensen/ed13w3_Ta2Se8I')
#       5 data1 = np.genfromtxt('lineplot_CDW_satellites_Toby_angled.csv', delimiter=',')
#       6 data2 = np.genfromtxt('lineplot_CDW_satellites_experimental_angled_secondary.csv', delimiter=',')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'F:/Jacob_Christensen/ed13w3_Ta2Se8I'

# %%
x1 = (data1[1:,0:1]*((245*0.01)/55))-max(data1[1:,0:1]*((245*0.01)/55))/2
y1 = data1[1:,1:2]
x2 = (data2[1:,0:1]*0.01)-max((data2[1:,0:1]*0.01))/2
y2 = data2[1:,1:2] - (min(data2[1:,1:2])-min(data1[1:,1:2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x1 = (data1[1:,0:1]*((245*0.01)/55))-max(data1[1:,0:1]*((245*0.01)/55))/2
#       2 y1 = data1[1:,1:2]
#       3 x2 = (data2[1:,0:1]*0.01)-max((data2[1:,0:1]*0.01))/2
#
# NameError: name 'data1' is not defined

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
#plt.ylim(0,200)

# %%
from matplotlib.gridspec import GridSpec

matplotlib.rcParams['font.sans-serif'] = "arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (7,5)

plt.plot(x2,y2,'blue',label='Synchrotron')
plt.plot(x1,y1,'red',label='Toby')

plt.ylabel('Intensity (a.u.)')
plt.xlabel('[0.05,0.05,0.1]')

plt.legend(numpoints=1,loc=[0.05,0.8],frameon=False,fontsize=17)

#plt.ylim(0,50)

#plt.show()

#plt.savefig('C:/Users/Jacob/Shoemaker_data/Figures/Ta2Se8I_Data/Tsi_Toby_Experimental_CDW_L=0.1_K=2.07.png',dpi=300,bbox_inches = 'tight', pad_inches = .018)

# %%
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.transforms as mtransforms
import matplotlib
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset, zoomed_inset_axes)

matplotlib.rcParams['font.sans-serif'] = "arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (7,5)
fig, ax = plt.subplots(1,1)

ax.plot(x2,y2,'blue',label='Synchrotron')
ax.plot(x1,y1,'red',label='Toby')

ax.set_ylabel('Intensity (a.u.)')
#ax.set_xlabel('[0.05,0.05,0.1]')
ax.set_xlabel('q (r.l.u.)')

ax.legend(numpoints=1,loc=[0.05,0.8],frameon=False,fontsize=17)
ax.tick_params('both', length=5, width=2.3, which='major')

axins = zoomed_inset_axes(ax, zoom=1, loc=1)
axins.plot(x2,y2,'blue',label='Synchrotron')
axins.plot(x1,y1,'red',label='Toby')
axins.set_xlim(-0.4,0.4)
axins.set_ylim(0,30)
# Manually set the position and relative size of the inset axes within ax1
ip = InsetPosition(axins, [0.19,0.19,0.81,0.81])
axins.set_axes_locator(ip)
for item in ([axins.title, axins.xaxis.label, axins.yaxis.label] +
             axins.get_xticklabels() + axins.get_yticklabels()):
    item.set_fontsize(15.5)
axins.tick_params('both', length=5, width=2, which='major')
# Mark the region corresponding to the inset axes on ax1 and draw lines
# in grey linking the two axes.
#mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec='0.5')
#axins.yaxis.set_major_locator(ticker.NullLocator())
#axins.xaxis.set_major_locator(ticker.NullLocator())
axins.patch.set_edgecolor('grey')  
axins.patch.set_linewidth(2)  

#plt.ylim(0,50)

#plt.show()

#plt.savefig('C:/Users/Jacob/Shoemaker_data/Ta2Se8I_Data/Figures/Tsi_Toby_Experimental_CDW_(0.05h,0.05k,0.1l).png',dpi=350,bbox_inches = 'tight', pad_inches = .018)

# %%
from matplotlib.gridspec import GridSpec

matplotlib.rcParams['font.sans-serif'] = "arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (7,5)

fig = plt.figure()
gs = GridSpec(2, 2, height_ratios=[3, 6])
ax = fig.add_subplot(gs.new_subplotspec((0, 0), colspan=2))
ax1 = fig.add_subplot(gs.new_subplotspec((1, 0), colspan=2))

#fig, (ax, ax1) = plt.subplots(2, 1, sharex=True)

#ax1.plot(x1,y1,'red',x2,y2,'blue')
ax1.plot(x1,y1,'red',label='Toby')
ax1.plot(x2,y2,'blue',label='Synchrotron')
ax.plot(x2,y2,'blue',label='Synchrotron')

ax.set_ylim(500,3500)  # outliers only
ax1.set_ylim(0, 170)  # most of the data 

ax1.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
#ax1.spines['top'].set_visible(False)
#ax1.spines['right'].set_visible(False)
#ax1.spines['bottom'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax1.xaxis.tick_bottom()
ax.get_xaxis().set_visible(False)
#ax1.get_xaxis().set_visible(False)


ax.set_yticks([1500,3500])
#ax.set_yticklabels([1.0])

d = .25  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax.plot([0], [0], transform=ax.transAxes, **kwargs)
ax1.plot([0], [1], transform=ax1.transAxes, **kwargs)
ax.plot([1], [0], transform=ax.transAxes, **kwargs)
ax1.plot([1], [1], transform=ax1.transAxes, **kwargs)

ax1.set_ylabel('Intensity (a.u.)')
ax1.yaxis.set_label_coords(-0.11, 0.7)
plt.xlabel('[H,2.07,0]')

ax1.legend(numpoints=1,loc=[0.05,1.3],frameon=False,fontsize=15)

# What's cool about this is that now if we vary the distance between
# ax and ax2 via f.subplots_adjust(hspace=...) or plt.subplot_tool(),
# the diagonal lines will move accordingly, and stay right at the tips
# of the spines they are 'breaking'

#plt.show()

plt.savefig('C:/Users/Jacob/Shoemaker_data/Figures/Ta2Se8I_Data/Tsi_Toby_Experimental_CDW_L=0.1_K=2.07.png',dpi=300,bbox_inches = 'tight', pad_inches = .018)

# %% [markdown]
# - Below we have script to plot the difference between synchrotron and Toby data for octagon satellites

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib

# %%
# 1901x1901 pixels experimental
# 511x511 pixels toby data
# each pixel in experimental is 0.01 reciprocal units
os.chdir('F:/Jacob_Christensen/ed13w3_Ta2Se8I')
data1 = np.genfromtxt('lineplot_Octagon_satellites_Toby_horizontal.csv', delimiter=',')
data2 = np.genfromtxt('lineplot_Octagon_satellites_experimental_horizontal.csv', delimiter=',')

# %%
x1 = (data1[1:len(data1)-5,0:1]*0.01*(1901/511))-max((data2[1:,0:1]*0.01))/2
y1 = data1[1:len(data1)-5,1:2] - (min(data1[1:len(data1)-8,1:2]) - min(data2[1:,1:2]))
x2 = (data2[1:,0:1]*0.01)-max((data2[1:,0:1]*0.01))/2
y2 = data2[1:,1:2]

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
matplotlib.rcParams['font.sans-serif'] = "arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (7,5)

plt.tick_params('both', length=5, width=2.3, which='major')
plt.plot(x1,y1,'red',label='Toby',alpha=0.5)
plt.plot(x2,y2,'blue',label='Synchrotron')
plt.ylim(6,21)
plt.ylabel('Intensity (a.u.)')
plt.locator_params(axis='y', nbins=5)
plt.xlabel('q (r.l.u.)')
plt.legend(numpoints=1,loc=[0.35,0.8],frameon=False,fontsize=17)
plt.savefig('C:/Users/Jacob/Shoemaker_data/Ta2Se8I_Data/Figures/Tsi_Toby_Experimental_Octagon_L=4_K=1.72.png',dpi=350,bbox_inches = 'tight', pad_inches = .018)

# %% [markdown]
# # Octagon peak comparison

# %%
from astropy.stats import SigmaClip
from photutils.background import Background2D, MedianBackground
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# first we will load in the background values near the bragg and octagon peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/synchrotron_planes')

# %%
data_test = np.genfromtxt('HK4.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# %%
synch_bragg_back = bkg.background[499,697]

# %%
synch_oct_back = bkg.background[533,631]

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/')

# %%
# this here finds the background values across the slice
# choose the size of each scanning window to use in the calculation (200,200)

data_test = np.genfromtxt('ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=4.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (200, 200), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# %%
toby_oct_back = bkg.background[292,318] #these show specific background values where I took lineslices

# %%
toby_bragg_back = bkg.background[282,336]

# %%
# now we will go ahead and load in our linecuts for the bragg peaks
# toby data has res of 2/53 rlu per pixel
# synch data has res of 0.01

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/synchrotron_planes')

# %%
data1 = np.genfromtxt('bragg_peak_profile_for_octagon_plot_synchrotron.csv', delimiter=',')
data2 = np.genfromtxt('bragg_peak_profile_for_octagon_plot_toby.csv', delimiter=',')

# %%
# we need the areas of the peaks for normalization
# to normalize, we divide by the area of the linecut, this makes the area normalized to exactly 1
# we subtract off the background, and multiply by res (rectangle method of integration)
synch_bragg_area = (np.sum(data1[1:,1:2])-synch_bragg_back)*0.01
toby_bragg_area = (np.sum(data2[1:,1:2])-toby_bragg_back)*2/53

# %%
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2]- synch_bragg_back)/synch_bragg_area
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2] - toby_bragg_back)/toby_bragg_area

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
# now we will go ahead and load in our linecuts for the octagon peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/synchrotron_planes')

# %%
data1 = np.genfromtxt('octagon_peak_profile_for_octagon_plot_synchrotron.csv', delimiter=',')
data2 = np.genfromtxt('octagon_peak_profile_for_octagon_plot_toby.csv', delimiter=',')

# %%
# we need the areas of the peaks for normalization
synch_oct_area = (np.sum(data1[1:,1:2])-synch_oct_back)*0.01
toby_oct_area = (np.sum(data2[1:,1:2])-toby_oct_back)*2/53

# %%
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2]- synch_oct_back)/synch_oct_area
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2] - toby_oct_back)/toby_oct_area

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
# this plot is not normalized
plt.plot(data1[1:,0:1]*0.01,data1[1:,1:2]-synch_oct_back)
plt.plot(data2[1:,0:1]*(2/53),data2[1:,1:2]-toby_oct_back)

# %% [markdown]
# # CDW peak comparison between synch and in-lab

# %% [markdown]
# - Use this section to plot linecuts taken through cdw peaks

# %%
from astropy.stats import SigmaClip
from photutils.background import Background2D, MedianBackground
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices')

# %%
# we need to subtract off the background levels from our slices
# let's start with the slices with the Bragg peaks
# first we will do synchrotron 

# this here finds the background values across the slice
# choose the size of each scanning window to use in the calculation (200,200)

data_test = np.genfromtxt('HK0.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices/HK0_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - now we will do the in-lab data

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/APEX_slices')

data_test = np.genfromtxt('ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=0.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/toby_slices/ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=0_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - now we do this same thing, but for the slices at the CDW peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices')

data_test = np.genfromtxt('HK0p1.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices/HK0p1_back_subtracted.csv',new_data,delimiter=",")

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/APEX_slices')

data_test = np.genfromtxt('ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=0.1.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/toby_slices/ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=0.1_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - Ok, we are ready to use imageJ to take the linecuts, be right back

# %%
# our linecut for the in-lab data has length of 69.67 pixels (2/53 rlu/pixel)
# we are looking at the two bragg peaks right below the origin
# therefore, the length in rlu is 69.67 * 2/53

# %%
(69.67 * 2/53)
# Out:
# 2.629056603773585

# %%
# therefore, the length for the synch data will be (69.67 * 2/53)/0.01 (since its res is 0.01 rlu/pixel)

# %%
(69.67 * 2/53)/0.01
# Out:
# 262.9056603773585

# %% [markdown]
# - ok, we are back. Here is the plots for the bragg peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('bragg_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('bragg_peaks_cdw_plots_toby.csv', delimiter=',')

# %%
# we need the areas of the peaks for normalization
# to normalize, we divide by the area of the linecut, this makes the area normalized to exactly 1
# we are using rectangle method here to integrate

synch_bragg_area = (np.sum(data1[1:,1:2]))*0.01
toby_bragg_area = (np.sum(data2[1:,1:2]))*2/53

# %%
x1 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y1 = (data1[1:,1:2])/synch_bragg_area
x2 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2
y2 = (data2[1:,1:2])/toby_bragg_area

# %%
# here are the bragg peaks
plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
# this shows that our curves are normalized... good!
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 1.0000000000000002
# 0.9999999999999998

# %%
# here are the plots not normalized
x1 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y1 = (data1[1:,1:2])
x2 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2
y2 = (data2[1:,1:2])
plt.plot(x1,y1)
plt.plot(x2,y2)

# %% [markdown]
# - Now, let's get our cdw linecuts and show those

# %%
# our linecut through the synch data is at y = 504 pixels
# the origin is at y = 400 pixels
# so, we are 104 pixels from the origin along the y direction
# the bragg peak is at about y = 499
# so our cdw satellites appear about 5 pixels away in the y direction from the bragg peaks
# so, in rlu, that is 5 * 0.01 = 0.05 rlu

# %%
0.05*(53/2)
# Out:
# 1.3250000000000002

# %%
# the above is the number of pixels away from the bragg peak we should take the lineslice in the toby data
# we find the bragg peak in toby data at y = 282 pixels. The origin is at y = 255.5 pixels
# therefore we should find the cdw peaks at about y = ...

# %%
282 + 0.05*(53/2)
# Out:
# 283.325

# %% [markdown]
# - We are ready to plot

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('cdw_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('cdw_peaks_cdw_plots_toby.csv', delimiter=',')

# %%
synch_bragg_area = (np.sum(data1[1:,1:2]))*0.01
toby_bragg_area = (np.sum(data2[1:,1:2]))*2/53

# %%
x3 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y3 = (data1[1:,1:2])/synch_bragg_area
x4 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2 - 0.06
y4 = (data2[1:,1:2])/toby_bragg_area

# %%
plt.plot(x3,y3)
plt.plot(x4,y4)

# %%
# this shows that our curves are normalized... good!
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 1.0
# 1.0

# %%
# here is the plots without normalization

x3 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y3 = (data1[1:,1:2])
x4 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2 - 0.06
y4 = (data2[1:,1:2])
plt.plot(x3,y3)
plt.plot(x4,y4)

# %% [markdown]
# - Now we want to find the ratios of the spillover, see if it makes sense that the toby data has the bragg peaks enveloping the cdw peaks
# - to do this, we can take the areas of the peaks and compare them. if it is substantial, we can assume swamping is happening

# %%
# here we find the areas for the bragg peaks

os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('bragg_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('bragg_peaks_cdw_plots_toby.csv', delimiter=',')
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2])
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2])

print('synch:',np.sum(y1)*0.01)
print('toby:',np.sum(y2)*(2/53))
# Out:
# synch: 440.06272999999993
# toby: 3155.8277735849056

# %%
# here we go for the cdw

os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('cdw_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('cdw_peaks_cdw_plots_toby.csv', delimiter=',')
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2])
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2])
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 444.62913000000003
# 824.8590943396224

# %% [markdown]
# - another idea, we can just look at the maximums for the peaks and compare those ratios

# %% [markdown]
# # Here we do it again, but at HK4

# %% [markdown]
# - Use this section to plot linecuts taken through cdw peaks

# %%
from astropy.stats import SigmaClip
from photutils.background import Background2D, MedianBackground
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices')

# %%
# we need to subtract off the background levels from our slices
# let's start with the slices with the Bragg peaks
# first we will do synchrotron 

# this here finds the background values across the slice
# choose the size of each scanning window to use in the calculation (200,200)

data_test = np.genfromtxt('HK4.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (200, 200), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices/HK4_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - now we will do the in-lab data

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/APEX_slices')

data_test = np.genfromtxt('ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=4.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/toby_slices/ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=4_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - now we do this same thing, but for the slices at the CDW peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices')

data_test = np.genfromtxt('HK4p1.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (200, 200), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/synchrotron_slices/HK4p1_back_subtracted.csv',new_data,delimiter=",")

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/APEX_slices')

data_test = np.genfromtxt('ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=4.1.csv', delimiter=',')
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(data_test, (100, 100), filter_size=(3, 3),
                   sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)

# and now, with the background levels, we subtract off the slice

new_data = data_test - bkg.background

# and go ahead and save this

np.savetxt('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/toby_slices/ed13w3_q_(h;0;0)(0;k;0)(0;0;l)=4.1_back_subtracted.csv',new_data,delimiter=",")

# %% [markdown]
# - Ok, we are ready to use imageJ to take the linecuts, be right back

# %%
# our linecut for the in-lab data has length of 69.67 pixels (2/53 rlu/pixel)
# we are looking at the two bragg peaks right below the origin
# therefore, the length in rlu is 69.67 * 2/53

# %%
(69.67 * 2/53)
# Out:
# 2.629056603773585

# %%
# therefore, the length for the synch data will be (69.67 * 2/53)/0.01 (since its res is 0.01 rlu/pixel)

# %%
(69.67 * 2/53)/0.01
# Out:
# 262.9056603773585

# %% [markdown]
# - ok, we are back. Here is the plots for the bragg peaks

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('bragg_peaks_cdw_plots_synch_HK4.csv', delimiter=',')
data2 = np.genfromtxt('bragg_peaks_cdw_plots_toby_HK4.csv', delimiter=',')

# %%
# we need the areas of the peaks for normalization
# to normalize, we divide by the area of the linecut, this makes the area normalized to exactly 1
# we are using rectangle method here to integrate

synch_bragg_area = (np.sum(data1[1:,1:2]))*0.01
toby_bragg_area = (np.sum(data2[1:,1:2]))*2/53

# %%
x5 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y5 = (data1[1:,1:2])/synch_bragg_area
x6 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2 - 0.017
y6 = (data2[1:,1:2])/toby_bragg_area

# %%
# here are the bragg peaks
plt.plot(x5,y5)
plt.plot(x6,y6)

# %%
# this shows that our curves are normalized... good!
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 1.0000000000000002
# 1.0

# %%
# here are the plots not normalized
x5 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y5 = (data1[1:,1:2])
x6 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2
y6 = (data2[1:,1:2])
plt.plot(x5,y5)
plt.plot(x6,y6)

# %% [markdown]
# - Now, let's get our cdw linecuts and show those

# %%
# our linecut through the synch data is at y = 504 pixels
# the origin is at y = 400 pixels
# so, we are 104 pixels from the origin along the y direction
# the bragg peak is at about y = 499
# so our cdw satellites appear about 5 pixels away in the y direction from the bragg peaks
# so, in rlu, that is 5 * 0.01 = 0.05 rlu

# %%
0.05*(53/2)
# Out:
# 1.3250000000000002

# %%
# the above is the number of pixels away from the bragg peak we should take the lineslice in the toby data
# we find the bragg peak in toby data at y = 282 pixels. The origin is at y = 255.5 pixels
# therefore we should find the cdw peaks at about y = ...

# %%
229 + 0.05*(53/2)
# Out:
# 230.325

# %% [markdown]
# - We are ready to plot

# %%
os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('cdw_peaks_cdw_plots_synch_HK4p1.csv', delimiter=',')
data2 = np.genfromtxt('cdw_peaks_cdw_plots_toby_HK4p1.csv', delimiter=',')

# %%
synch_bragg_area = (np.sum(data1[1:,1:2]))*0.01
toby_bragg_area = (np.sum(data2[1:,1:2]))*2/53

# %%
x7 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y7 = (data1[1:,1:2])/synch_bragg_area
x8 = data2[1:,0:1]*(2/53) - max((data2[1:,0:1]*2/53))/2 - 0.03
y8 = (data2[1:,1:2])/toby_bragg_area

# %%
plt.plot(x7,y7)
plt.plot(x8,y8)

# %%
# this shows that our curves are normalized... good!
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 0.9999999999999999
# 1.0

# %%
# here is the plots without normalization

x7 = data1[1:,0:1]*0.01 - max((data1[1:,0:1]*0.01))/2
y7 = (data1[1:,1:2])
x8 = data2[1:,0:1]*(2/53)-0.06 - max((data2[1:,0:1]*2/53))/2
y8 = (data2[1:,1:2])
plt.plot(x7,y7)
plt.plot(x8,y8)

# %% [markdown]
# - Now we want to find the ratios of the spillover, see if it makes sense that the toby data has the bragg peaks enveloping the cdw peaks
# - to do this, we can take the areas of the peaks and compare them. if it is substantial, we can assume swamping is happening

# %%
# here we find the areas for the bragg peaks

os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('bragg_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('bragg_peaks_cdw_plots_toby.csv', delimiter=',')
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2])
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2])

print('synch:',np.sum(y1)*0.01)
print('toby:',np.sum(y2)*(2/53))
# Out:
# synch: 440.06272999999993
# toby: 3155.8277735849056

# %%
# here we go for the cdw

os.chdir('C:/Users/Jacob/Shoemaker_Data/Ta2Se8I_Data/ed13w3_Ta2Se8I_APEX_slices_linecuts/linecuts_cdw/linecuts')
data1 = np.genfromtxt('cdw_peaks_cdw_plots_synch.csv', delimiter=',')
data2 = np.genfromtxt('cdw_peaks_cdw_plots_toby.csv', delimiter=',')
x1 = data1[1:,0:1]*0.01
y1 = (data1[1:,1:2])
x2 = data2[1:,0:1]*(2/53)
y2 = (data2[1:,1:2])
print(np.sum(y1)*0.01)
print(np.sum(y2)*(2/53))
# Out:
# 444.62913000000003
# 824.8590943396224

# %% [markdown]
# - another idea, we can just look at the maximums for the peaks and compare those ratios

# %% [markdown]
# # Plotting plots for CDW peak comparison

# %%
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.transforms as mtransforms

matplotlib.rcParams['font.sans-serif'] = "arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
plt.rcParams.update({'font.size': 20})
plt.rcParams["figure.figsize"] = (7,5)

fig, ax = plt.subplots(2,2,figsize=(13,13))
fig.subplots_adjust(wspace = 0.125,hspace = 0.07)

plot1 = ax[0,0].plot(x1,y1,c='blue',linewidth=1,marker='o',markersize=3.2,label='Synchrotron')
plot2 = ax[0,0].plot(x2,y2,c='red',linewidth=1,marker='^',markersize=3.2,label='In-lab')
plot3 = ax[0,1].plot(x3,y3,c='blue',linewidth=1,marker='o',markersize=3.2,label='Synchrotron')
plot4 = ax[0,1].plot(x4,y4,c='red',linewidth=1,marker='^',markersize=3.2,label='In-lab')
plot5 = ax[1,0].plot(x5,y5,c='blue',linewidth=1,marker='o',markersize=3.2,label='Synchrotron')
plot6 = ax[1,0].plot(x6,y6,c='red',linewidth=1,marker='^',markersize=3.2,label='In-lab')
plot7 = ax[1,1].plot(x7,y7,c='blue',linewidth=1,marker='o',markersize=3.2,label='Synchrotron')
plot8 = ax[1,1].plot(x8,y8,c='red',linewidth=1,marker='^',markersize=3.2,label='In-lab')

#plot9 = ax[0,0].scatter(x1,y1,c='blue',s=16)
#plot10 = ax[0,0].scatter(x2,y2,c='red',s=16,marker='^')
#plot11 = ax[0,1].scatter(x3,y3,c='blue',s=16)
#plot12 = ax[0,1].scatter(x4,y4,c='red',s=16,marker='^')
#plot13 = ax[1,0].scatter(x5,y5,c='blue',s=16)
#plot14 = ax[1,0].scatter(x6,y6,c='red',s=16,marker='^')
#plot15 = ax[1,1].scatter(x7,y7,c='blue',s=16)
#plot16 = ax[1,1].scatter(x8,y8,c='red',s=16,marker='^')

ax[0,0].set_xlabel('$\mathit{q}$ (r.l.u.)')
#ax[0,1].set_xlabel('$\mathit{q}$ (rlu)')
ax[1,0].set_xlabel('$\mathit{q}$ (r.l.u.)')
ax[1,1].set_xlabel('$\mathit{q}$ (r.l.u.)')

ax[0,0].set_ylabel('Intensity (a.u.)')
ax[1,0].set_ylabel('Intensity (a.u.)')

#ax[1,1].set_ylim(0,30)

ax[0,0].yaxis.set_major_locator(plt.MaxNLocator(4))
ax[1,0].yaxis.set_major_locator(plt.MaxNLocator(4))
ax[0,1].yaxis.set_major_locator(plt.MaxNLocator(4))
ax[1,1].yaxis.set_major_locator(plt.MaxNLocator(5))

ax[0,0].yaxis.set_tick_params(width=2.5)
ax[0,0].xaxis.set_tick_params(width=2.5)
ax[1,0].yaxis.set_tick_params(width=2.5)
ax[1,0].xaxis.set_tick_params(width=2.5)
ax[0,1].yaxis.set_tick_params(width=2.5)
ax[0,1].xaxis.set_tick_params(width=2.5)
ax[1,1].yaxis.set_tick_params(width=2.5)
ax[1,1].xaxis.set_tick_params(width=2.5)

ax[0,0].yaxis.set_tick_params(length=5.3)
ax[0,0].xaxis.set_tick_params(length=5.3)
ax[1,0].yaxis.set_tick_params(length=5.3)
ax[1,0].xaxis.set_tick_params(length=5.3)
ax[0,1].yaxis.set_tick_params(length=5.3)
ax[0,1].xaxis.set_tick_params(length=5.3)
ax[1,1].yaxis.set_tick_params(length=5.3)
ax[1,1].xaxis.set_tick_params(length=5.3)

ax[0,0].label_outer()
ax[0,1].axes.xaxis.set_ticklabels([])

trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
ax[0,0].text(0.0, 1.0, '(a) HK0', transform=ax[0,0].transAxes + trans,
        fontsize=18, position=(0.0,0.955),
        bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax[0,1].text(0.0, 1.0, '(b) HK0.1', transform=ax[0,1].transAxes + trans,
        fontsize=18, position=(0.0,0.955),
        bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax[1,0].text(0.0, 1.0, '(c) HK4', transform=ax[1,0].transAxes + trans,
        fontsize=18, position=(0.0,0.955),
        bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))
ax[1,1].text(0.0, 1.0, '(d) HK4.1', transform=ax[1,1].transAxes + trans,
        fontsize=18, position=(0.0,0.955),
        bbox=dict(facecolor='0.8', edgecolor='none', pad=3.0))

ax[0,0].legend(loc=[0.3,0.8],fontsize=15)

plt.savefig('C:/Users/Jacob/Shoemaker_data/Ta2Se8I_Data/Figures/TSI_CDW_Peak_Comparison.png',dpi=170,bbox_inches = 'tight', pad_inches = .018)
